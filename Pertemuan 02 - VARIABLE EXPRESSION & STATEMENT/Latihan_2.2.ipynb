# %%
x = int(input("Masukkan nilai x (bilangan bulat): "))

if x != 0:
    hasil = 2 * (x ** 3) + 2 * x + (15 / x)
    print("Nilai f(x) adalah:", hasil)
else:
    print("Nilai x tidak boleh 0")
# Out:
# Masukkan nilai x (bilangan bulat):  8
# Nilai f(x) adalah: 1041.875
